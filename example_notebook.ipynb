# %% [markdown]
# # Section 1

# %%
print('this is some code')

some_variable = 5
# Out:
# this is some code

# %% [markdown]
# # Section 2

# %%
print('this is some more code')
# Out:
# this is some more code

# %%
import matplotlib.pyplot as plt

plt.scatter([1, 2, 3], [4, 5, 4])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
